# %%
import requests
import json

webhook_url = "https://hook.eu1.make.com/tkz9t362xcz1y44efmdo6og4c7377tc7"

data = {
    "product_title": "مكنسة البخار",
    "gpc_code": "10000732"
}

response = requests.post(webhook_url, json=data)
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#    "final_score": 0
#    "Product title Generated": This product is a steam cleaner, a type of household appliance designed for deep cleaning and sanitization. Its primary function is to utilize high-temperature steam to effectively remove dirt, grease, and grime from various surfaces, making it suitable for floors, upholstery, and hard surfaces. The device likely operates by heating water to produce steam, which is then expelled under pressure for cleaning purposes.,
#    "Product Title": Feeding/Eating Bibs,
#    "Definition Includes": Includes any products that can be described/observed as a garment specifically designed for use in feeding and typically intended to provide a degree of convenience and/or protection for clothing, or safety and comfort. Products include items such as rigid plastic bibs, fabric bibs and disposable bibs made from polythene or absorbent fibres.,
# ...
